# %%
# %matplotlib inline
import backtrader as bt
import matplotlib as plt
import yfinance as yf

# %%
BEKE_data = yf.download('BEKE')
#	Open	High	Low	Close	Adj Close	Volume
#Date						
#2020-08-13	35.060001	37.490002	31.790001	37.439999	37.439999	49492400
#2020-08-14	33.810001	35.950001	32.500000	33.000000	33.000000	10652200
#2020-08-17	33.450001	39.000000	33.400002	38.720001	38.720001	8806500
BEKE_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-08-13  35.060001  37.490002  31.790001  37.439999  37.439999  49492400
# 2020-08-14  33.810001  35.950001  32.500000  33.000000  33.000000  10652200
# 2020-08-17  33.450001  39.000000  33.400002  38.720001  38.720001   8806500
# 2020-08-18  40.130001  43.000000  38.110001  40.500000  40.500000   7961900
# 2020-08-19  40.500000  48.099998  39.900002  42.369999  42.369999  13581200
# ...               ...        ...        ...        ...        ...       ...
# 2022-06-27  19.160000  19.350000  17.969999  18.010000  18.010000  24748200
# 2022-06-28  18.030001  18.110001  17.385000  17.760000  17.760000  12136100
# 2022-06-29  17.820000  18.040001  17.330000  17.760000  17.760000   9237300
# 2022-06-30  17.400000  17.950001  16.934999  17.950001  17.950001   7998200
# ...

# %%
BEKE_data.rename(columns={'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Adj Close': 'adj_close', 'Volume': 'volume'}, inplace=True)

# %%
cerebro = bt.Cerebro()

# %%
class A_Strategy(bt.Strategy):
    pass

# %%
data = bt.feeds.PandasData(dataname = BEKE_data)

# %%
cerebro.addstrategy(A_Strategy)
cerebro.adddata(data)

# %%
cerebro.run()

# %%
#plt.rcParams['figure.figsize'] = [15, 12]
#plt.rcParams.update({'font.size': 12}) 
cerebro.plot(iplot=False)
# Out:
# [[<Figure size 1080x864 with 4 Axes>]]
